# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('seaborn-talk')
fig = plt.figure(figsize=(6,4))
ax = plt.axes()
x = np.linspace(0,20,1500)
y = np.cos(x)
ax.plot(x,y,color='orange',linestyle='dashed')
ax.set(xlim=(1,14),ylim=(-1,1.2),xlabel='X-values',
       ylabel='Y-values',title='my-graph')
# Out:
# [(1.0, 14.0),
#  (-1.0, 1.2),
#  Text(0.5, 0, 'X-values'),
#  Text(0, 0.5, 'Y-values'),
#  Text(0.5, 1.0, 'my-graph')]
