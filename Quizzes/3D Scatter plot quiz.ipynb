# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
X = np.random.normal(0,5,50)
Y = np.random.normal(0,5,50)
Z = np.random.normal(0,5,50)
ax.scatter(X,Y,Z,c='g',marker='.',alpha=0.6)
X = np.random.normal(10,9,70)
Y = np.random.normal(10,9,70)
Z = np.random.normal(10,9,70)
ax.scatter(X,Y,Z,c='y',marker='+',alpha=0.6)
# Out:
# /tmp/ipykernel_48552/3197505799.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
