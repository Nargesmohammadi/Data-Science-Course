# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
sns.relplot(x='sepal_width',y='petal_length',data=iris,
            hue='sepal_length',style='species')
