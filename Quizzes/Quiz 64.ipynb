# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax = plt.subplots(2,4,figsize=(4,3),sharex='col',sharey='row')
for i in range(2):
    for j in range(4):
        ax[i,j].imshow(np.random.rand(200,200),plt.cm.coolwarm)
        ax[i,j].set(xticks=[],yticks=[])
