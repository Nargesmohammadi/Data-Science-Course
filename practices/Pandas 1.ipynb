# %%
import pandas as pd

# %%
A = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])

# %%
A.values
# Out:
# array([1, 2, 3, 4])

# %%
A.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
A['a':'c']
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
marks_dic = {'A':7, 'B':8, 'C':12, 'D':9}
marks = pd.Series(marks_dic)
marks
# Out:
# A     7
# B     8
# C    12
# D     9
# dtype: int64

# %%
marks.values
# Out:
# array([ 7,  8, 12,  9])

# %%
marks.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
marks['A']
# Out:
# 7

# %%
marks[0 : 2]
# Out:
# A    7
# B    8
# dtype: int64

# %%
grade_dic = {'A':2.4, 'B':3, 'C':5, 'D':4}
grades = pd.Series(grade_dic)

# %%
D = pd.DataFrame({'Marks':marks, 'Grades':grades})
D
# Out:
#    Marks  Grades
# A      7     2.4
# B      8     3.0
# C     12     5.0
# D      9     4.0

# %%
D.T
# Out:
#           A    B     C    D
# Marks   7.0  8.0  12.0  9.0
# Grades  2.4  3.0   5.0  4.0

# %%
D.values
# Out:
# array([[ 7. ,  2.4],
#        [ 8. ,  3. ],
#        [12. ,  5. ],
#        [ 9. ,  4. ]])

# %%
D.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
D.values[2,0]
# Out:
# 12.0

# %%
D.columns
# Out:
# Index(['Marks', 'Grades'], dtype='object')

# %%
D['ScaleMarks'] = 100*(D['Marks']/90)
D
# Out:
#    Marks  Grades  ScaleMarks
# A      7     2.4    7.777778
# B      8     3.0    8.888889
# C     12     5.0   13.333333
# D      9     4.0   10.000000

# %%
del D['ScaleMarks']
D
# Out:
#    Marks  Grades
# A      7     2.4
# B      8     3.0
# C     12     5.0
# D      9     4.0

# %%
G = D[D['Marks']>8]
G
# Out:
#    Marks  Grades
# C     12     5.0
# D      9     4.0

# %%
A = pd.DataFrame([{'a':1, 'b':3}, {'b':-3, 'c':9}])
A
# Out:
#      a  b    c
# 0  1.0  3  NaN
# 1  NaN -3  9.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  1.0  3  0.0
# 1  0.0 -3  9.0

# %%
A.dropna
# Out:
# <bound method DataFrame.dropna of      a  b    c
# 0  1.0  3  NaN
# 1  NaN -3  9.0>

# %%
A = pd.Series(['a', 'b', 'c'], index=[1, 2, 6])
A[1]
# Out:
# 'a'

# %%
A[1:3]
# Out:
# 2    b
# 6    c
# dtype: object

# %%
A.loc[1:3]
# Out:
# 1    a
# 2    b
# dtype: object

# %%
A.iloc[1:3]
# Out:
# 2    b
# 6    c
# dtype: object

# %%
D
# Out:
#    Marks  Grades
# A      7     2.4
# B      8     3.0
# C     12     5.0
# D      9     4.0

# %%
D.iloc[2, :]
# Out:
# Marks     12.0
# Grades     5.0
# Name: C, dtype: float64

# %%
D.iloc[::-1,:]
# Out:
#    Marks  Grades
# D      9     4.0
# C     12     5.0
# B      8     3.0
# A      7     2.4

# %%
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('../L1/003 salaries-by-college-major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.drop(['Starting Median Salary', 'Group'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      Undergraduate Major  Mid-Career Median Salary  \
# 0             Accounting                   77100.0
# 1  Aerospace Engineering                  101000.0
# 2            Agriculture                   71900.0
# 3           Anthropology                   61500.0
# 4           Architecture                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0

# %%
df.rename(columns={'Undergraduate Major':'Major'}, inplace=True)
df.head()
# Out:
#                    Major  Mid-Career Median Salary  \
# 0             Accounting                   77100.0
# 1  Aerospace Engineering                  101000.0
# 2            Agriculture                   71900.0
# 3           Anthropology                   61500.0
# 4           Architecture                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0

# %%
df.describe()
# Out:
#        Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# count                  50.00000                          50.000000
# mean                74786.00000                       43408.000000
# std                 16088.40386                       12000.779567
# min                 52000.00000                       26700.000000
# 25%                 60825.00000                       34825.000000
# 50%                 72000.00000                       39400.000000
# 75%                 88750.00000                       49850.000000
# max                107000.00000                       71900.000000
#
#        Mid-Career 90th Percentile Salary
# count                          50.000000
# mean                       142766.000000
# std                         27851.249267
# min                         96400.000000
# 25%                        124250.000000
# 50%                        145500.000000
# 75%                        161750.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Major                              51 non-null     object
#  1   Mid-Career Median Salary           50 non-null     float64
#  2   Mid-Career 10th Percentile Salary  50 non-null     float64
#  3   Mid-Career 90th Percentile Salary  50 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.7+ KB

# %%
nmum =df.replace({'NA':10})
nmum
# Out:
#                                    Major  Mid-Career Median Salary  \
# 0                             Accounting                   77100.0
# 1                  Aerospace Engineering                  101000.0
# 2                            Agriculture                   71900.0
# 3                           Anthropology                   61500.0
# 4                           Architecture                   76800.0
# 5                            Art History                   64900.0
# 6                                Biology                   64800.0
# 7                    Business Management                   72100.0
# 8                   Chemical Engineering                  107000.0
# 9                              Chemistry                   79900.0
# 10                     Civil Engineering                   90500.0
# 11                        Communications                   70000.0
# 12                  Computer Engineering                  105000.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                    Major Mid-Career Median Salary  \
# 0                             Accounting                  77100.0
# 1                  Aerospace Engineering                 101000.0
# 2                            Agriculture                  71900.0
# 3                           Anthropology                  61500.0
# 4                           Architecture                  76800.0
# 5                            Art History                  64900.0
# 6                                Biology                  64800.0
# 7                    Business Management                  72100.0
# 8                   Chemical Engineering                 107000.0
# 9                              Chemistry                  79900.0
# 10                     Civil Engineering                  90500.0
# 11                        Communications                  70000.0
# 12                  Computer Engineering                 105000.0
# ...

# %%
df.head(10)
# Out:
#                    Major  Mid-Career Median Salary  \
# 0             Accounting                   77100.0
# 1  Aerospace Engineering                  101000.0
# 2            Agriculture                   71900.0
# 3           Anthropology                   61500.0
# 4           Architecture                   76800.0
# 5            Art History                   64900.0
# 6                Biology                   64800.0
# 7    Business Management                   72100.0
# 8   Chemical Engineering                  107000.0
# 9              Chemistry                   79900.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# ...

# %%
# Out:
#                                    Major Mid-Career Median Salary  \
# 0                             Accounting                  77100.0
# 1                  Aerospace Engineering                 101000.0
# 2                            Agriculture                  71900.0
# 3                           Anthropology                  61500.0
# 4                           Architecture                  76800.0
# 5                            Art History                  64900.0
# 6                                Biology                  64800.0
# 7                    Business Management                  72100.0
# 8                   Chemical Engineering                 107000.0
# 9                              Chemistry                  79900.0
# 10                     Civil Engineering                  90500.0
# 11                        Communications                  70000.0
# 12                  Computer Engineering                 105000.0
# ...

# %%
df1 = nmum.groupby('Major')[['Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary']].sum().reset_index()

# %%
df1
# Out:
#                                    Major  Mid-Career Median Salary  \
# 0                             Accounting                   77100.0
# 1                  Aerospace Engineering                  101000.0
# 2                            Agriculture                   71900.0
# 3                           Anthropology                   61500.0
# 4                           Architecture                   76800.0
# 5                            Art History                   64900.0
# 6                                Biology                   64800.0
# 7                    Business Management                   72100.0
# 8                   Chemical Engineering                  107000.0
# 9                              Chemistry                   79900.0
# 10                     Civil Engineering                   90500.0
# 11                        Communications                   70000.0
# 12                  Computer Engineering                  105000.0
# ...

# %%
df2 = df1[df1['Mid-Career Median Salary']>100000.0]
df2
# Out:
#                      Major  Mid-Career Median Salary  \
# 1    Aerospace Engineering                  101000.0
# 8     Chemical Engineering                  107000.0
# 12    Computer Engineering                  105000.0
# 19  Electrical Engineering                  103000.0
#
#     Mid-Career 10th Percentile Salary
# 1                             64300.0
# 8                             71900.0
# 12                            66100.0
# 19                            69300.0
